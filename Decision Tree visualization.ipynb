# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
# %matplotlib inline

# %%
import warnings 
warnings.filterwarnings("ignore")

# %%
diabetes = pd.read_csv(r"C:\Users\Sirisha\Downloads\diabetes.csv")
diabetes
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
x= diabetes.drop(['Outcome'],1)
y = diabetes['Outcome']

# %%
x.head(1)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
#
#    DiabetesPedigreeFunction  Age
# 0                     0.627   50

# %%
y.head(1)
# Out:
# 0    1
# Name: Outcome, dtype: int64

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier(random_state=10,max_depth=3)
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(max_depth=3, random_state=10)

# %%
from sklearn import tree
plt.figure(figsize=(25,25))
tree.plot_tree(model, feature_names=diabetes.columns, filled=True);
